# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set(palette='rainbow')

# %% [markdown]
# #### Sci-kit Blobs data

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=300,n_features=2,centers=5,cluster_std=1.8,random_state=123)

# %%
data[0].shape
# Out:
# (300, 2)

# %%
#visualize it

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow');

# %% [markdown]
# #### Cluster

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=5)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 4.48698028, -5.63838522],
#        [ 0.38698681, -2.21247509],
#        [ 9.41186075,  3.95474171],
#        [ 4.81167293, -1.47629085],
#        [-5.2978504 ,  0.44168667]])

# %%
kmeans.labels_ #predicted label
# Out:
# array([4, 2, 0, 0, 1, 3, 0, 3, 0, 2, 4, 3, 3, 3, 3, 1, 4, 3, 1, 1, 3, 4,
#        2, 0, 1, 4, 0, 3, 3, 1, 4, 4, 3, 3, 0, 1, 2, 1, 4, 2, 4, 2, 3, 4,
#        2, 0, 2, 4, 4, 4, 2, 2, 1, 4, 1, 0, 1, 2, 1, 1, 0, 3, 3, 3, 3, 1,
#        0, 1, 3, 4, 3, 2, 0, 2, 1, 4, 3, 4, 0, 0, 4, 3, 1, 3, 2, 3, 3, 1,
#        1, 1, 1, 2, 4, 4, 1, 0, 4, 0, 3, 3, 1, 1, 2, 3, 1, 1, 4, 2, 1, 1,
#        4, 1, 3, 3, 4, 3, 4, 3, 2, 4, 0, 1, 3, 1, 4, 4, 0, 4, 1, 0, 0, 1,
#        1, 0, 2, 1, 2, 1, 1, 2, 4, 2, 0, 1, 4, 2, 3, 2, 3, 1, 2, 0, 1, 2,
#        4, 0, 3, 4, 4, 3, 0, 0, 1, 1, 4, 3, 2, 4, 4, 1, 1, 4, 4, 2, 0, 3,
#        3, 2, 2, 1, 1, 2, 4, 2, 1, 4, 2, 2, 1, 3, 4, 1, 4, 0, 3, 2, 0, 0,
#        1, 2, 0, 1, 1, 0, 3, 2, 3, 3, 3, 3, 1, 2, 3, 4, 2, 1, 4, 4, 2, 3,
#        3, 4, 3, 1, 4, 1, 3, 2, 2, 2, 1, 3, 2, 2, 2, 1, 1, 3, 2, 0, 4, 4,
#        1, 2, 4, 3, 4, 3, 1, 4, 1, 3, 0, 4, 3, 0, 3, 3, 1, 2, 2, 4, 4, 1,
#        3, 3, 2, 0, 0, 2, 2, 4, 2, 3, 1, 1, 4, 1, 2, 4, 2, 0, 1, 1, 4, 1,
#        4, 0, 3, 3, 0, 1, 2, 3, 2, 4, 1, 2, 4, 3])

# %%
#comparing with original label
data[1]
# Out:
# array([1, 3, 0, 0, 4, 0, 0, 4, 0, 3, 1, 2, 2, 2, 2, 2, 1, 0, 0, 4, 2, 1,
#        3, 0, 4, 4, 0, 0, 2, 4, 1, 1, 2, 2, 0, 4, 2, 4, 1, 3, 1, 3, 4, 1,
#        3, 0, 3, 1, 1, 1, 3, 3, 4, 1, 4, 0, 2, 3, 4, 4, 0, 0, 0, 2, 2, 4,
#        0, 4, 2, 1, 0, 3, 0, 3, 4, 1, 2, 1, 0, 2, 1, 2, 4, 2, 3, 2, 2, 4,
#        4, 2, 4, 3, 1, 1, 0, 0, 1, 0, 0, 0, 4, 0, 3, 2, 4, 2, 1, 3, 4, 4,
#        1, 0, 2, 2, 1, 0, 1, 2, 3, 1, 2, 4, 4, 4, 1, 1, 0, 1, 4, 0, 0, 4,
#        2, 0, 3, 0, 3, 4, 4, 3, 4, 3, 0, 4, 1, 3, 2, 3, 2, 4, 3, 0, 0, 3,
#        1, 4, 0, 1, 1, 2, 0, 0, 0, 0, 1, 0, 3, 1, 1, 4, 4, 1, 1, 3, 0, 2,
#        0, 3, 3, 4, 4, 3, 1, 3, 4, 4, 3, 3, 4, 2, 1, 4, 1, 0, 2, 3, 0, 0,
#        4, 3, 2, 4, 4, 0, 2, 3, 2, 0, 2, 0, 4, 3, 4, 1, 3, 4, 1, 1, 3, 2,
#        0, 1, 2, 2, 1, 4, 2, 3, 3, 3, 2, 2, 3, 3, 3, 4, 2, 2, 3, 0, 1, 1,
#        4, 3, 1, 2, 1, 4, 4, 1, 2, 2, 0, 1, 2, 0, 3, 2, 4, 3, 3, 1, 1, 4,
#        0, 2, 3, 2, 2, 3, 3, 1, 3, 2, 2, 2, 1, 4, 3, 1, 3, 0, 2, 4, 1, 4,
#        1, 0, 2, 3, 0, 2, 3, 0, 3, 1, 4, 3, 1, 0])

# %%
#Scatter plot
fig,(ax1,ax2) =plt.subplots(1,2,sharey=True,figsize=(10,5))

ax1.set_title('Predicted Data')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')


ax2.set_title('Origina Data')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')


plt.show()
